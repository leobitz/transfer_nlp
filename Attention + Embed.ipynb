# %%
import tensorflow as tf
from tensorflow.keras.layers import Embedding
import numpy as np
from data_gen import *
import time
import preprocess as pre

# %%
char2int, feat2val, max_r, max_w = pre.process(['wol'])
data = pre.convert(char2int, feat2val, max_r, max_w, langs=['wol'])
test_data = pre.convert(char2int, feat2val, max_r, max_w, langs=['wol'], train_set=False)
int2char = {val: key for val, key in enumerate(char2int)}

# %%
batch_size = 128
max_root = max_r + 2
max_word = max_w + 2
n_feature = data[1].shape[1]
hidden_size = 256
feat_embed_size = 32
char_embed_size = 96
n_batches = len(data[0]) // batch_size
print("Total Data: {0} Total Batches {1}".format(len(data[0]), n_batches))
# Out:
# Total Data: 14780 Total Batches 115

# %%
class Encoder(tf.keras.Model):
    def __init__(self, enc_units, feat_units, batch_size):
        super(Encoder, self).__init__()
        self.batch_size = batch_size
        self.enc_units = enc_units
        self.gru = tf.keras.layers.GRU(self.enc_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform', name="encoder_gru")
        self.fc1 = tf.keras.layers.Dense(feat_units, activation="relu", name="feature_output")
        self.fc2 = tf.keras.layers.Dense(enc_units, activation="relu", name="state_out")
        
    def call(self, w, f, hidden):
        output, state = self.gru(w, initial_state=hidden)
        feat = self.fc1(f)
        state = tf.concat([state, feat], axis=1)
        state = self.fc2(state)
        return output, state, feat

    def initialize_hidden_state(self):
        return tf.zeros((self.batch_size, self.enc_units), dtype=tf.float32)

# %%
class BahdanauAttention(tf.keras.Model):
    def __init__(self, units):
        super(BahdanauAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V = tf.keras.layers.Dense(1)

    def call(self, query, values):
        # hidden shape == (batch_size, hidden size)
        # hidden_with_time_axis shape == (batch_size, 1, hidden size)
        # we are doing this to perform addition to calculate the score
        hidden_with_time_axis = tf.expand_dims(query, 1)

        # score shape == (batch_size, max_length, 1)
        # we get 1 at the last axis because we are applying score to self.V
        # the shape of the tensor before applying self.V is (batch_size, max_length, units)
        score = self.V(tf.nn.tanh(
            self.W1(values) + self.W2(hidden_with_time_axis)))

        # attention_weights shape == (batch_size, max_length, 1)
        attention_weights = tf.nn.softmax(score, axis=1)

        # context_vector shape after sum == (batch_size, hidden_size)
        context_vector = attention_weights * values
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %%
class Decoder(tf.keras.Model):
    def __init__(self, dec_units, output_size, batch_size):
        super(Decoder, self).__init__()
        self.batch_size = batch_size
        self.dec_units = dec_units
        self.gru = tf.keras.layers.GRU(self.dec_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform', name="decoder_gru")
        self.fc = tf.keras.layers.Dense(output_size, activation="softmax")

        self.attention = BahdanauAttention(self.dec_units)

    def call(self, x, hidden, enc_output, feat):
        # enc_output shape == (batch_size, max_length, hidden_size)
        context_vector, attention_weights = self.attention(hidden, enc_output)

        x = tf.concat([context_vector, x, feat], axis=-1)
        x = tf.expand_dims(x, 1)
        output, state = self.gru(x, initial_state=hidden)
        output = tf.reshape(output, (-1, output.shape[2]))

        x = self.fc(output)
        return x, state#, attention_weights

# %%
decoder = Decoder(hidden_size, len(char2int), batch_size)
encoder = Encoder(hidden_size, feat_embed_size, batch_size)
emb = Embedding(len(char2int), char_embed_size, input_length=max_word, name="char_embedding")

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.CategoricalCrossentropy()

def loss_function(real, pred):
    loss_ = loss_object(real, pred)

    return tf.reduce_mean(loss_)

# %%
@tf.function
def train_step(root, feature, dec_input, target, enc_hidden):
    loss = 0
    
    with tf.GradientTape() as tape:
        x = emb(root)
        enc_output, enc_hidden, feat = encoder(x, feature, enc_hidden)

        dec_hidden = enc_hidden

        for t in range(target.shape[1]):
            x = emb(dec_input[:, t])
            predictions, dec_hidden = decoder(x, dec_hidden, enc_output, feat)
            loss += loss_function(target[:, t], predictions)

        batch_loss = (loss / int(target.shape[1]))
        variables = encoder.trainable_variables + decoder.trainable_variables

        gradients = tape.gradient(loss, variables)
    optimizer.apply_gradients(zip(gradients, variables))

    return batch_loss

# %%
def predict(encoder, decoder, inputs, n_steps):
    # encode
    root, feat = inputs[0], inputs[1]
    x = emb(root)
    enc_hidden = encoder.initialize_hidden_state()
    enc_output, state, feat = encoder(x, inputs[1], enc_hidden)
    
    start_word = '<'
    start_mat = pre.word_to_matrix(start_word, char2int, 1, ' ')
    
    target_seq = np.zeros((root.shape[0], len(char2int)), dtype=np.float32) + np.array(start_mat, dtype=np.float32)
    x = emb(target_seq.argmax(axis=1))
#     print(target_seq.shape)
    outputs = list()
    for t in range(n_steps):
        # predict next char
        
        target_seq, state = decoder(x, state, enc_output, feat)
        
        yhat = np.array(target_seq).argmax(axis=1)
        x = emb(yhat)
        outputs.append(target_seq)
    return np.stack(outputs)

# %%
def test_model():
    test_n_batches, test_batch_size =  int(test_data[0].shape[0] / batch_size), batch_size  
    print(test_n_batches * test_batch_size)
    test_gen = pre.gen(data, batch_size)
    # shows sample examples and calculates accuracy
    test_batches = len(test_data[0]) // batch_size
    total, correct = 0, 0
    in_word = 0
    sims = []
    for b in range(test_batches - 1):
        # get data from test data generator
        [root, feat, dec_in], y = next(test_gen)
        pred = predict(encoder, decoder, [root, feat], max_word)
        for k in range(pred.shape[1]):
            indexes = pred[:, k].argmax(axis=1)
            r = ''.join(pre.index_to_word(root[k], int2char)).strip()[1:-1]
            w = ''.join(pre.index_to_word(dec_in[k], int2char)).strip()[1:-1]
            t = ''.join(pre.index_to_word(indexes, int2char)).strip()[:-1]
            if w == t:
                correct += 1
            else:
                print(r, w, t)


        total += batch_size
        return float(correct)/float(total)*100.0

# %%
# test_model()

# %%
EPOCHS = 10
gen = pre.gen(data, batch_size)

# %%
for epoch in range(EPOCHS):
    start = time.time()

    enc_hidden = encoder.initialize_hidden_state()
    total_loss = 0

    for step in range(n_batches):
        [root, feat, dec_in], y = next(gen)
        batch_loss = train_step(root, feat, dec_in, y, enc_hidden)
        total_loss += batch_loss

#         if step % (n_batches // 1) == 0:
#             print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
#                                                      step,
#                                                      batch_loss.numpy()))
    accuracy = test_model()
    print('Epoch {} Loss {:.4f} Accuracy {:.4f}'.format(epoch + 1,
                                      total_loss / n_batches, accuracy))
    
#     print(accuracy)
#     print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# 4352
# boljjojj boljjojjssaanaari baaaaaaaaassaaaaaa
# sulumuum sulumuumissibeenna baaaaaassssssaaa
# oshinchch oshinchchissibeokkona maaahhhhtissssseeeeee
# sirqq sirqqida saaaisiiee
# koyzz koyzzideta saaaiiieee
# arqq arqqogaa saaaiaaa>
# me'' me''ssona saaisssia
# me'' me''iyagaa saaiiiyoe
# daaxx daaxxaas saaaassaa
# pooqq pooqqssiyaree saaasssssaa
# uray urayissageetee saaisssogeeee
# toonnot toonnotissibeokko baaaatissssieeeee
# marss marssidogee maaaiiigee
# ufaytt ufayttssaanaara saaaaasssaaaaa
# sir sirissiyogaa saissssagee
# huus huusissoree saassssaaa
# tamaar tamaaridora maaaaaaaaa
# zigg ziggssidaro sarssssaa
# keed keediis saaasiaa
# zawr zawrissiyo saisssssiee
# mammot mammotissidara saaaassssaaa
# kamm kammssogoo saassssaeee
# dembbay dembbayissidora saaaaassssaaa
# goodett goodettssogaa saaaasssssaaee
# puyxay puyxayidi saaaiisiee
# laazzatt laazzattssadee baaaaaasssssaa
# ampp amppidoree saaaaaaa
# war waridagee saaaaaae
# gaaddet gaaddetiyoro maaaaaaiiaa
# mood moodissabeikkinaa saassssseeeee
# surqq surqqenna saaaaaaaa
# donjjill donjjillssaanaageetu baaaaaaaasssaaaaaaeeee
# booramm boorammssidoro saaaaassssaa
# shull shullona maaaaaaa
# afuxx afuxxssakka saaaasssaaa
# ezgg ezggssana saaasssaaaa
# dirqqall dirqqallssadasa saaaaaasssssaa
# gad gadiyogeetu saaiiigeee
# wud wudaanaageetu saaaaaaaaeee
# iit iitissoppo saissssaa
# qaqqaas qaqqaasageeta maaaaaaaageeee
# suuppay suuppayissaanaageeti saaaaaasssaaaaaaeee
# luukk luukkagoo saaaaaaaee
# looh loohiyagaa saaaiiyag
# sholloorett sholloorettssogeetee haahhhhhissssseeeeeee
# minjj minjjagoo saaaaaaaee
# cabbott cabbottssiyogeeta saaaassssssggeeee
# laazzatt laazzattssidaro maaaaaassssaaa
# sheekk sheekkees saaaaasaa
# kappikapp kappikappssokkona maallhhttssssikkk
# hanttaar hanttaarissidara maaaaaasssssaa
# zooq zooqissidageeta saassssseeeee
# ayllet aylletissiyagaa saalisssssaaee
# xomat xomatidogeeti baaaiiaeeee
# sham shamissaanaara saaaassaaaaaa
# lee' lee'issokkonii saaisssseeeee
# cuuph cuuphogee maaaiiigeee
# ho'' ho''ssogoo saaisssoeeee
# bocc boccidagee saaaaaaa
# borxxoxx borxxoxxssiis baaaaaassssssaa
# deddot deddotabeikke baaaaaaaaaa
# koshoshatt koshoshattibeettenna baaaahhtttiiieeeee
# bulxx bulxxssiyogeeta saaasssssogeeee
# goora gooraissanne saaaisssaaaa
# goy goyissanne saisssiaaa>
# harqq harqqageetu saaaaaageee
# shaatt shaattssabeekkee saaaaissssaaa>
# garchch garchchissakka baaaaaassssaaa
# awaas awaasissiyaro saaasssssaa
# xam xamona saaaaa
# kurum kurumissidonaa saaiisssiieee
# shir shirissaasi saasssssaa
# phopholqqatt phopholqqattssibeennee haalhhhhhissssssikknnnn
# suubaal suubaalissettenna baaaatsssssseeee
# buu'ulatt buu'ulattssaanaaree haaaaaaaaaasaaaaaaaa
# gadull gadullssido saaaisssssieee
# maagul maagulissiyageeti maaaisssssoeeeee
# qaqqaas qaqqaasidagaa maaaaaaaaaa
# galluntt gallunttogeeti maaaaaaaiageeee
# zoox zooxissekketa saaisssieeee
# gi'' gi''ido saaiiiieee
# goxx goxxssidageetoo saassssoeeeeee
# afuut afuutissabeukku saaasssssaa
# purcc purccissikkinaa saaaisssskkk
# tookk tookkssidogeeti saaassssageeee
# halqquntt halqqunttiyageeta maallhhhiiyygeeee
# daadulmat daadulmatiyaree maalaaaaaaaaa
# xooet xooetiyogeeti maaaiiigeeee
# duwarss duwarssssekketa saaaaassssseeee
# gundd gunddssiyageetee maaaissssoeeeee
# eh ehiissibeokkonii saisssieeeee
# gonn gonnennee saaaaaaee
# jaggott jaggottssidaro saaaaassssaa
# lazzatt lazzattibeokkona maaaaatiieeeeee
# gololatt gololattssoree maaaaaassssaaa
# muum muumissidagee saaisssageee
# sokkay sokkayiyogoo maaaaaiyagee
# wargg warggssibeokkonaa saaaisssieeeeeee
# paachchur paachchuriyogee maaaaaaaaaaaggee
# kaakk kaakkssiyogeeta saaisssssogeeee
# adab adabissaydaa saaassssa
# sagg saggssiyogeetee saaissssogeeee
# harbbuuq harbbuuqissiyori maalaaassssssaa
# pirxx pirxxiyanaa saaaaiia
# tooss toossaanaaro saaaaaaaaaa
# molddodd molddoddsseeta maalattssssia
# gubaay gubaayidanaa saaaaisiaa
# azzantt azzanttssoppa saaaaaisssaaa
# geemm geemmssidori saaassssaa
# gorxx gorxxssekkee saaasssssaa
# wozannaam wozannaamiyagaa maallhhhiiiyaa
# kalloy kalloyissogeeta saaasssssoeeeee
# att attokkonii saaiieeeee
# yuu yuuissidogeeta saisssseeeee
# suq suqageeta saaaggeeee
# loq loqissuuteetii saissssie
# heessoy heessoyiyora maaaaaaaaaa
# ukkum ukkumaanaaree saaaaaaaaaaa
# zurgg zurggssibeokkona saaassssseeeee
# mereet mereetaasa saaaaaaa
# yiiqet yiiqetidogeetoo baaaaiieeeeeee
# baq baqissoos saissssii
# ho hoissii saisssa
# haaxx haaxxssokko saaasssssoee
# tullay tullayissiyogeetoo saaaasssssogeeeee
# awaaqet awaaqetagee maaaaaaaaaee
# zuuzumm zuuzummidogeetee maaaaaiigeeeee
# loox looxiyageeti saaiiiygeeee
# Epoch 1 Loss 1.4976 Accuracy 0.0000
# 4352
# qiljjijj qiljjijjaanaageetee manaaattaaaageeetee
# buu'ulatt buu'ulattidaree maraaaattidore
# oxx oxxidonii garisieeii
# shirqqiiq shirqqiiqaas maraaaataaaa
# shug shugidageeta kariidogeeto
# xuuqq xuuqqssabeikkii maratissibeekkaa
# abaraad abaraadissageeti maraaatissageete
# arggaac arggaacaanaagoo manaaaaaaaaaagee
# corphphay corphphayiyonaa morhhaattioona
# poonn poonnaree maraaaare
# ef efabeukku aaribeeka
# sayll saylliis maratisa
# wayq wayqisseettees martissooo
# zenkk zenkkssiyari maratissiyara
# jaggott jaggottiyagaa maraattiyoge
# uush uushida martiseeti
# diiq diiqidaro kariidara
# ganxx ganxxuutee maratideee
# gorccay gorccayidogeetu maraaatidageett
# kaac kaacuutee maraaaeee
# sulkkoy sulkkoyidee maraaatidaee
# kar karekkee karikkkk
# qaac qaacissidagoo marisssidagee
# kaa kaaissiyogoo karissiyogeee
# sholloorett sholloorettssabeukku morhhatttttssssekkka
# bogg boggiyogeetoo kariiyoggeeto
# kafot kafotissaas maratissada
# palah palahissona maratissi
# si' si'issagaa aarissagee
# tor torissaas marisssaa
# qunxx qunxxssibeekketa maratissibekkkee
# leellees leelleesaanaagoo manaaaaaaaaaaagee
# meed meedoos martioo
# kinchchiriir kinchchiriiridageetoo horhhhhttttigogeeto
# amman ammanissoo maratissideeta
# muyratt muyrattssiyogeetee maraattissiygeette
# darccuntt darccunttssiyageetoo maraaaattssiyogeetto
# maganxx maganxxaanaageetoo manaaaaaaaaageeeto
# kuuy kuuyissari karisssarara
# warqqall warqqallanaa maraaaaaaaaa
# jarijar jarijaroree maraaatidoro
# san'' san''ssiyageetoo maratissiyogeeto
# laamm laammiyari maratiyara
# lag lagara aarara
# dil dilissidogoo marissidogee
# annaac annaacissadee maraatissidee
# beerott beerottssara maraattssara
# looqqoy looqqoyissaanaageetee maraaatsssaaaageeete
# gimbb gimbbiyageetee maratiyogeett
# jawl jawlissibeettennee garisssibeeeteeeee
# zoozet zoozetogeeti marattidogeet
# baaxet baaxetogoo maraatidogee
# sheephet sheephetu marhaaatuu
# molddodd molddoddssideta maraaaatissideee
# paachchur paachchuraasi maraaaaaataaa
# qaarat qaaratogeetee maraatidogeet
# cirpp cirppssidi maratissida
# gaw'' gaw''ssada maratisssa
# anjj anjjidageetee martidgeeetee
# yakak yakakiyonii garatiooo
# xuf xufissiyara karissiyara
# guufet guufetidari maraatidara
# toppay toppayiyoro karaatiyara
# tirxx tirxxo maratiyo
# kayyott kayyottiyageetee maraattiyogeete
# ustt usttaree karaagee
# leel leelissiyageetee mariissiyogeett
# guntt gunttiyanaa garatisa
# peenot peenotiyagaa marattiyogee
# handdaraash handdaraashogeetee morhhhhttttigeette
# leeqqam leeqqamibeokkonii maraaatiseetkeeei
# zo zoaanaagee aanaaaagee
# zilil zililissaas maratsssada
# digg digganai maaaaaa
# bunjjibunjj bunjjibunjjssidogeeta morhhhttttissidogeette
# murxx murxxo marati
# guurumm guurummibeokkona maraaatibeekkkna
# gitett gitetteetii garattieeti
# bolkkay bolkkayiyogeeti maraaatiyageett
# dinddoy dinddoyoppite maraatteettee
# shelleqatt shelleqattssogeeti maraaaattissidogeet
# qix qixissaasi marisssaa
# qoncc qonccaanaageetee manaaaaaaageetee
# qinjjillatt qinjjillattssabeikkinaa mirhaattttisssibekkkka
# goottar goottarissibeettenna maraaatissseeeeteee
# zuuzumm zuuzummanne maraaaaanana
# di' di'issaanaaree sarissaaaaaaa
# payy payyssibeekketii garisssibeekkeeei
# darax daraxidogoo maratidogee
# wocam wocamissori maratissidare
# qooroy qooroyakka maraaaakkka
# bulakk bulakkoos maraatioo
# kachachch kachachchaanaageeti manbaaaataaaaaageeta
# yoot yootekketa markkkkko
# allag allagissabeakka maratissabekkka
# muc mucissakka karissekkka
# moozott moozottana maraaaaaaa
# gish gishissokko martissokkko
# xaall xaallabeekkee maratibeekkee
# sall sallidee martidana
# gaacc gaaccissoppona maratissopeee
# umbbubul umbbubulissiyageetoo maraaattissiyogeetto
# miiqq miiqqenna markkkkkk
# yexx yexxssaanaagee karasssaaaaaaa
# dirim dirimettennee martteeettee
# xikkill xikkillibeokkona maraattibeekkeee
# gaytalatt gaytalattaanaagoo monnaaataaaaaagee
# shereq shereqogeeti marattidogeet
# boroq boroquuteetii maratideette
# wud wudaanaageetu manaaaaageeto
# zenkk zenkkssoppite maratisseettee
# aad aadissiyageeta marissiyogeeta
# halaqat halaqatissikkii maraaatissekkka
# kaset kasetadasa maaaaaaaa
# millijj millijjidogee maraattidagee
# kurum kurumidogeeti marttidogeete
# zozz zozzssibeokkonaa marisssibeekkknni
# puxuruur puxuruurissogaa maraaattissidage
# kuuy kuuyissite marisssoee
# lassan lassaniyagaa maraatiyagee
# haggaaz haggaazissidogee maraaatissidagee
# qucucay qucucayissikkinaa maraaatissikkkka
# toofatt toofattssidoro maraattissidara
# shaall shaalleeta maraatioo
# kinkkill kinkkillssaanaaree maraaattsssaaaaaaa
# purgg purggogee maratidoge
# shinqqiriir shinqqiriirikkii hilhhattttkkkka
# qol qolissa marissa
# Epoch 2 Loss 1.0026 Accuracy 0.0000
# 4352
# pisiss pisissssada sissssssaaa
# birshsh birshshissaanaagaa sonkkotissaanaaga
# saassot saassotissibeokkonii borbaatissibeekkonii
# hurppay hurppayissiyogee paraaayissiyagee
# kuulumul kuulumulissageeti sulluuulissageeta
# qoh qohissabeukku sidissabeekke
# qumbbat qumbbatoos baraaatiyo
# zawr zawraasu aaalaasa
# inggaaz inggaazissoro ganaaatissido
# qocir qocirissiyagee pookhissiyagee
# cay cayissidogeetu aagissidogeeta
# looqqott looqqottidoro toocoottidora
# kokkor kokkorennee sooootokke
# kalloy kalloyissogeeta paraatissidogee
# bulakk bulakkssidogeeti paaaalissidogeeti
# munn munnssidonaa borissidonii
# dichch dichchidonaa soodotidonii
# pedukk pedukkssadii surdayissadaa
# shuush shuushissoro sookosissoro
# zaachch zaachchissiyoro baraaatissiyora
# qilliic qilliicissaanaaree silbaalissaanaaree
# ichch ichchiyo goootidona
# inddetaasu inddetaasuissiyageetu hilibicattissiyogeetu
# miiqq miiqqana suulaanaa
# sheleeshsh sheleeshshaanaageeta soshhhhhhhaanaageeta
# deell deellssiyaree sulkhissiyoro
# aan aanissidageetu aagissidageeta
# maq maqeeta aayaya
# gangg ganggabeikkinaa gaagtabeekkii
# achch achchissabeekkee baaatissabeekkee
# laggett laggettidogeetee ganatttidageetee
# qoophatt qoophattssogaa goncotttissoga
# mirxxixat mirxxixatibeettenna bilbbaattibeeteeta
# yafar yafarokkona aaaayokkonaa
# saaphot saaphotissaanaageeti banbaattssaanaageeta
# duuxer duuxerissibeenna sureelissibeenaa
# shonggatt shonggattssikkii gonhhatttssikki
# gaannat gaannatadii gaaaaataaaaa
# corphphay corphphayiyogeeti honhhaaatiyogeeti
# phool phoolibeettenna gooctibeeteeta
# shoocatt shoocattekketa gonhoottetketa
# gerzzum gerzzumissara soreeetissara
# maash maashidogaa paaalidogoo
# pisiss pisissoro sookorido
# yoot yootaasi tootidaa
# eeyy eeyyiyagoo sooyiyogee
# tiif tiifekketa tottettetna
# jabbukett jabbukettssibeokkonii garbaaattissibeekkonai
# lososs losossagaa soooooora
# pagg paggssiyonii aaatissiyona
# metoy metoyoppite goootopteeta
# serggex serggexissiyari horeeetissiyora
# doynatt doynattidageetee gonotttidageetee
# naass naassidageeti paaalidogeeti
# yaat yaatissiyanaa aaatissida
# dagay dagayaro aaaatara
# qumaay qumaayiyoro qaaaayiyara
# yolomoom yolomoomidora sooshootidora
# xoom xoomibeekketii gootibeetketii
# qoqoqay qoqoqayissidageeta surbbayissidogeeta
# xs xsissokko iiissokkona
# ar ariyori aaiiyara
# wuttaal wuttaalokkonii ganaaatikkonii
# phalqq phalqqssibeekketa baabayissibeekkena
# priix priixidara banctidara
# kabbash kabbashissiyoree baraaatissiyoroo
# ud udaro siara
# boc bocogoo gogogoo
# ar araanaageeti aaaanaageeti
# miqqaynn miqqaynnssidogoo shibbaalissidogoo
# dugunuun dugunuunissabeikkii shibbaatissabeekkii
# talbbott talbbottssukku gangattttssekku
# qoophatt qoophattaanaageetu gonchattaanaageeta
# balbbuq balbbuqissibeekketa baabaalissibeekkenaa
# koxx koxxibeokko sookibkokko
# wosttaq wosttaquutee gonchotidee
# qeeqqaalett qeeqqaalettssiyanaa hillilaaatissida
# lasass lasassssaydaa baraalissidaasa
# medhdh medhdhissaro sookkhissara
# qoncc qonccida sooddido
# harbbuuq harbbuuqissiyagoo harbaaayissiyogee
# aatt aattssidogee gagtissidogee
# suufar suufarissiyagee qullayissiyogee
# zohaa zohaaibeennee baaatibeekkee
# gaxay gaxayay aaaatanee
# booccot booccotissiyoro toooottissiyora
# koy koyidonaa soridonna
# takkaar takkaarogee gaaaaatidagee
# yabacatt yabacattidageetoo gaabaattidogeetoo
# dar darissiyagee aayissiyagaa
# dicc dicciyori gootiyara
# mal malissiyonaa aayissiyonaa
# aal aalisseettees aagissido
# corphphay corphphayissadii horhhaaatissadaa
# muuxx muuxxssidogee pulxqissidogee
# wooss woossssaanaageetee sooshssaanaageetee
# zawat zawatissoppo gaagtissoppa
# baas baasissidogeeti aaalissidogeeti
# qaqaqatt qaqaqattssoppa gaabaaatissappa
# yololl yolollssaanaagee sonkktssaanaagee
# yuuqiyuuq yuuqiyuuqissidogeeta sulqquuqissiyogeeta
# eeq eeqidogeetoo soyidogeetoo
# biiribiir biiribiirissidogaa hilidicatissidaga
# halchch halchchissibeekketa harbaatissibeekkenaa
# dur durissaanaageetoo bilissaanaageetoo
# poox pooxenna gookokka
# laagg laaggaanaageeti aaaataanaageeta
# galat galatissibeekketii aaaatissibeekkenii
# seel seelissidonii soolissidonii
# salqqisalqq salqqisalqqidoree silqqiqaalidaroro
# barott barottssidogaa ganattissidoga
# hoskkatt hoskkattssageetoo goncoottssageetoo
# qull qullssiyogeeti palqissiyageeti
# markkay markkayissogeeti paraaatissidogee
# wayq wayqissogee paalissidoga
# gaaxaat gaaxaatekketii aaaaaatikkonaa
# leebbaashet leebbaashetada hilbhaaaaaaaaa
# konkkom konkkomoo soochotiyo
# xexxel xexxelogeetu bulxayidogee
# paaf paafissidonaa aaagissidonai
# murunn murunnoppo surxayoppo
# xuuss xuussssanne suuxssannana
# bay bayawsu aalaa
# lakakatt lakakattssiyori gaabaattissiyora
# guntt gunttibeekketa gonttabeetketa
# buhey buheyidari suuddadara
# wodeenn wodeenniyaro sookootiyora
# Epoch 3 Loss 0.7591 Accuracy 0.7812
# 4352
# ishshoy ishshoyissiyogeeta sheshesissiyogeeta
# gagett gagetti gaggtti
# buraaq buraaqogaa aaaaalidogaa
# seref serefissaree seeesssaree
# carbbabatt carbbabattssada gangaaaattssada
# gam'' gam''iyanaa gaggayii
# zawr zawraasu aaarida
# jawl jawlissabeakka aaalissabeikka
# xitt xittiyonaa tittiyonaa
# gaytalatt gaytalattssuutee gagggatttssiu
# shirqqiiq shirqqiiqokkonaa siiqiqiliyoononaa
# goodett goodettssidagee googottssidagee
# mucuraak mucuraakissidageetoo baraaaalissidogeetoo
# kitikit kitikitennee tilittteetee
# guufett guufettssiiddi geeggttssiido
# inddetaasu inddetaasuissidageeta banhbhaaatissidogeeta
# sheekk sheekkabeekkee sheessabeekkee
# phalqq phalqqogeetee qaruxidogeetee
# phuuphull phuuphullssaasu burubuussssadu
# pilgg pilggssogeetu gilitissidogee
# muxux muxuxissiyageetee quuqqssiyageetee
# kuuy kuuyabeukku suuqabeekku
# xanna xannaissokkonaa aaaatissokkonaa
# jabalatt jabalattuppu gaagaattuppu
# qaph qaphoos aaayiyo
# luhett luhettssekkee geeettsseekee
# shicc shiccaanaaro sooriaanaara
# xuqay xuqayaanaaree qaallaanaaree
# gitett gitettibeenna tittttibeenna
# qiib qiibissoppa lillissippa
# boqos boqosii sooroo
# bollot bollotissaanaagoo gorettssaanaagoo
# kalkkot kalkkotogeeta gangattogeeta
# hususatt hususattssibeokkonii barhaatissibeekkonii
# shiggichch shiggichchissekketa hinhhhhhhtssekketa
# kebb kebbssa shayissi
# geess geessidogeeti seeelidogeetee
# xeell xeellettidi siiqqidaa
# eexx eexxssuuteetii eeelissoteetie
# harshshuush harshshuushissibeekketa hhshhhhhhhsssibeekketa
# tobb tobbssidageetu goggssidogeetu
# ess essssaanaaree sesssaanaaree
# sholaat sholaatiyonaa ganhaatiyonaa
# kayat kayataree aaagaaree
# barggaag barggaagissidoro gaagaattssidoro
# phanqqal phanqqaliyogee haraaayiyogee
# shimpp shimppiyogeeta seeeeliyogeeta
# gorshshay gorshshayissibeenna honhhhashssibeetna
# hanccaqarot hanccaqarotissageeta ganggaaatttssageeta
# saassot saassotidageeta baraasidogeeta
# tembbereer tembbereerissabeikke billibishassibeekke
# balgg balgguuteetii gaggtiuteetie
# xaqqay xaqqayabeakka qaaallabeikka
# unbbubul unbbubulissibeettennee buuluuulissibeettennee
# kash kashidara kaaridari
# butat butatissidee gaggtsside
# qawcay qawcayissaanaageeta aaaaayissaanaageeta
# qakk qakkiyogaa aaayiyogaa
# bunjjibunjj bunjjibunjjssidara billilililisssidara
# morgget morggetissageetu goretttssageetu
# yaat yaatissaanaari aaatissaanaari
# kimbbish kimbbishissibeokko shelleelissibeokko
# xooh xoohiyageetee googiyageeti
# tuyr tuyriyogeeta giggiyogeeta
# xorkkot xorkkotissibeokko goreeetissibeokko
# saag saagageeta aaagageeta
# sirimm sirimmssoos seeeelissoo
# agamas agamasissaanaageeta aaaaatssaanaageeta
# geet geetibeokkona tittibeekkona
# gagis gagisissaasi gaggtssida
# por poraas dorads
# allaxx allaxxssogeetu aalallssidogeetu
# lee' lee'issidetii eeelissidetii
# holssiholss holssiholssssukku sheshshshisssukku
# yoot yootogeetoo googogeetoo
# narphph narphphissogeetoo harhaatissogeetoo
# kokkor kokkoraanaageetee bookoyaanaageetee
# xuugg xuuggssogoo gulllisoooo
# gidd gidda gidaa
# tashaasu tashaasuiyo hanaaaayidetii
# lassan lassanissidogaa qaaaalissidogaa
# dagamm dagammabeikkinaa aaaaalibeikkinaa
# uukk uukkssidageeti buulissidageeti
# qorccay qorccayanai hanhaayanaa
# lokkatt lokkattssibeokkonii garggttssibeokkonii
# xambbet xambbetidogeeta garaattidogeeta
# xonggoll xonggolloppona gonchotoppona
# polttamm polttammssidagee gorggattssidogee
# lushushsh lushushshissiyoree sheshshusissiyoree
# jeeret jeeretissidagoo geeeetissidogee
# zo zoissidogaa eiissidogaa
# looxiloox looxilooxoree soorhooridoree
# dom domissaanaaree besissaanaaree
# mulssuss mulssussssibeekketii suuquussssibeekketii
# si' si'abeikke eeibbekkee
# minddat minddatissettennee gareettssibeetnenne
# dembbatt dembbattekketii ganggattetketii
# butt buttibeokkonii gagtibeokkonii
# baar baarogeetu aaagidogee
# pirxx pirxxssiyora mililissiyora
# paacc paaccissideta aaaatissideti
# ceegg ceeggiyo goggtidetii
# uzuuz uzuuzukku suulqakku
# ayllet aylletadasa gallttaasa
# poshshatt poshshattssiyogee honhhaattssiyogee
# paachchur paachchurogeetoo banhaaaatogeetoo
# pushal pushalissidanaa haraayissida
# tiy tiyiyageeta tigiyogeeta
# kitikit kitikitiyonaa tiritttiyonaa
# dalall dalallssukku aalallsseekku
# wolloq wolloqiyoro soreshiyora
# nagg naggekketii gaggettetii
# amal amalissaas aaalssada
# seell seelliyageetee seelliyogeeti
# daabul daabulissaanaagoo aaaaalssaanaagoo
# kaalot kaalotissidogaa gaaggtssidogaa
# keemm keemmssidora seesissidori
# keer keerissiyageetoo seesissiyogeetoo
# binjjibinjj binjjibinjjssogeeti bilililililissideetee
# duubbal duubbalissidogeeta qaruuulissidogeetu
# shuuy shuuyidi suussidi
# pannis pannisissaanaageeti banaatssaanaageeti
# porshsh porshshaanaaro shoshoyaanaara
# hum humissabeekkee bulissabeekkee
# ohett ohettaanaageetee goottaanaageetee
# sokisoll sokisolliyagaa sooshosiyogaa
# dombbolo'' dombbolo''idora bonhhhooridora
# loox looxikke gookokka
# Epoch 4 Loss 0.5759 Accuracy 0.0000
# 4352
# xalal xalalibeekketa qaallibeetketa
# ishal ishalaree shammaree
# aakim aakimaanaageeta aaasaanaageeta
# xee xeeissori ee'issori
# bor borissori porissida
# zeelumm zeelummidageeta seeeeelidageeta
# qoncc qonccissoppona pooccssoppona
# kelkk kelkkekketii kekkkekketii
# gurub gurubissaanaaro duuddssaanaaro
# handdaraash handdaraashakka hanchaaaashakka
# tincc tinccissagee ginggssidagee
# gadull gadullssido duramissido
# gaaxx gaaxxssidagee aaaxxssidagee
# biixibiix biixibiixana xiiliiixxana
# dagg daggssageetee gaggssageetee
# puur puuruutee puuduutee
# tanggacc tanggaccissidosona garggaatissidonana
# sheephet sheephetu sheeeeetu
# hunchch hunchchidee hunhhhhide
# toofatt toofattuuteetii coocottouteetii
# qoc qocissikkii oocissikkii
# qayxaar qayxaaroppona qaalaayoppo
# xurumbb xurumbbssabeukku buubuulissabeukku
# qinjjiqinjj qinjjiqinjjssidagaa gilijijijjjssidagaa
# morkkett morkkettssoro kolpoottssoro
# cadakk cadakkida haaachido
# kalkkoy kalkkoyissaas kashaatissads
# mallis mallisidogeeta qallllidogeeta
# xurumbb xurumbbssettenna xuubuuxissettenna
# maash maashissiyageetee aaashssiyageetee
# inggaaz inggaazissibeenna garddayissibeenna
# bulhhay bulhhayidageeti shabbayidageeti
# phanqqal phanqqaliyogee saraqaamiyogee
# qoociqooc qoociqoocissogeetoo poooooootissogeetoo
# wodall wodallssabeikkinaa harayssibbikkinaa
# leemis leemisissabeikkinaa seelelissabeikkinaa
# ashkkar ashkkarekketa sashashekketa
# sooq sooqissidori soomissidori
# kutuut kutuutidoro puunctidoro
# aradd araddssekketa aaaayiseekketa
# ayf ayfissidari aarissidari
# shuuqq shuuqqaree suuumqaree
# kawshsh kawshshiyori shashshiyori
# qunot qunotiyaro punctiyara
# qachch qachchtidonaa kashayibsokkonaa
# giddot giddotikkii giddddakki
# arkkot arkkotissidoro kakkotissororo
# midiid midiidissada giriddssada
# qoos qoosissidee sooyissidee
# acoy acoyagaa kaocagaa
# kaay kaayissiyori aaayissiyori
# seexiseex seexiseexaasi seelleeelaasi
# unkkot unkkotadee kurettadee
# keed keediis seehids
# meecc meeccissidogeetee peeecissidogeetee
# mugg muggiyogaa guggiyogaa
# kichichch kichichchabeukku shophhhhhibeukku
# molssoss molssossikkinaa sossssssikkinaa
# seet seetiyageeti eeetiyageeti
# bay bayiyagaa aayiyagaa
# qawcalatt qawcalattidagee qaalaaattidagee
# boqos boqosaanaaree sooshaanaaree
# wonzz wonzzogee pooccogee
# hiil hiilissees zixxssee
# wozannaam wozannaamissidageetoo harabaaayissidageetoo
# hoskkatt hoskkattanee koshaatanee
# amoy amoyagee kayhagee
# xiill xiillaanaageeti xilllaanaageeti
# pooll poollssaanaagoo poooyissaanaagoo
# zinqq zinqqssennee xirqqssennee
# sabb sabbiyogoo kashiyogoo
# tennejjatt tennejjattidogoo tiribicattidogoo
# pix pixuppu xiruppu
# ciiyy ciiyyssiyageeti giyiyissiyageeti
# duchchis duchchisissaanaari hunhhhhhssaanaari
# hit hitissara tetissara
# kayyoy kayyoyissidari hoshayissari
# yeellay yeellayissiyogeetu perbbayissiyogeetu
# boqos boqosageeti sooshageeti
# shut shutissiyanaa shchissiyanaa
# shiiqq shiiqqidari siiqqqara
# konkkarss konkkarssidoro shoshasssidoro
# darqquntt darqqunttabeikkii qarbbaatibbikkii
# ull ulliyageeti xuliyageeti
# kaachchifat kaachchifatissabeakka karcchachatissabeakka
# gawhay gawhayiyoro haraayiyoro
# danqq danqqssogaa daaqissidogaa
# zuumm zuummssidagee suumqssidagee
# darqquntt darqqunttssidogaa garjaattssidogaa
# meezey meezeyissidanaa peeeerissidanaa
# gooshsh gooshshekkee sooshoyekkee
# xorphphay xorphphayissikkii shorhchayissikki
# gececc gececcees peeeetee
# diljj diljjssaanaari xilixissaanaari
# laallantt laallanttaanaaro qallaatttanaara
# murggat murggatissidonii gardaatissidonii
# dagantt daganttssees gaggattssee
# deell deellidageetoo xeexxidageetoo
# shirqqiiq shirqqiiqissiis siiqqqiqqssids
# zom zomissokkonaa soyissokkonaa
# woraajj woraajjikke saaraayekka
# zuyr zuyrissekketa zudbssekketa
# dawwal dawwaliyanaa aaraayiya
# buraat buraatibeokko aaraatibeokko
# gagis gagisissadasa gayddssadaa
# qull qullssidori qullssidari
# solkkay solkkayissiyaree sookkayissiyaree
# mulccatt mulccattssagaa pullatttssagaa
# sakkett sakkettssidora kakkkttssidora
# lokkatt lokkattays kolaattays
# suugg suuggssoos puuncssoo
# loo'iloo' loo'iloo'iyageetu poolooootiyageetu
# solakk solakkssana shakkkssana
# tincc tinccidageeta tinggidageeta
# kokkor kokkorabeakka kokkokabeikka
# guupp guuppssiyonaa duuddssooonaa
# adaraas adaraasissiyogeetee aaaaaamissiyogeetee
# gorshshay gorshshayissiyogeeti shorhasayissiyogeeti
# bashsh bashshissibeokkonii shashsssibeokkonii
# demm demmiyageeta seiyiyageeta
# cuwatt cuwattaanaagee aanattaanaagee
# irzziiz irzziiziyanaa giridayiys
# ef efabeukku eeibeukku
# phenqqesh phenqqeshoo sheshheshiu
# tifilatt tifilattekkee tiribatteekee
# yambbar yambbaragee saaraayagee
# lakk lakkssiyageeti kashssiyageeti
# Epoch 5 Loss 0.4459 Accuracy 0.7812
